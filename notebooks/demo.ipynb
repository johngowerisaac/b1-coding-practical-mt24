# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/johngowerisaac/Important/Oxford/Academic/Year 3/B1/Scientific Coding/b1-coding-practical-mt24/.venv/lib/python3.12/site-packages']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
import sys
import os

# Add the path to the uuv_mission directory without moving files
uuv_mission_path = os.path.abspath('../uuv_mission')  # This will go up one directory and then into uuv_mission
sys.path.append(uuv_mission_path)

# Now import specific classes from dynamic
from dynamic import Submarine, Mission, ClosedLoop
from control import PDController

# Print current working directory for debugging
# print("Current Working Directory:", os.getcwd())

# Verify the path to the CSV file
# csv_path = '../data/mission.csv'
# print("Does the CSV file exist?", os.path.exists(csv_path))

sub = Submarine()
# Instantiate your controller (depending on your implementation)
submarine = Submarine()
mission = Mission.from_csv()  # Ensure the CSV file path is correct
controller = PDController(Kp=0.15, Kd=0.6)

# Create a ClosedLoop instance
closed_loop = ClosedLoop(submarine, controller)

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
